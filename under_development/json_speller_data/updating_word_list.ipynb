# %%
import pandas as pd
word_dictionary = pd.read_json('./words_dictionary.json', typ='series')
word_dict = list(word_dictionary.keys())

# %%
word_dict=list(set(word_dict))

# %%
word_dict.append('unironic')
word_dict.append('paninis')
word_dict.append('chilis')
word_dict.append('niblet')
word_dict.append('niblets')
word_dict.append('cyber')
word_dict.append('glute')
word_dict.append('glutes')
word_dict.append('ramen')
word_dict.append('firebomber')
word_dict.append('firefights')
word_dict.append('firehorse')
word_dict.append('cardio')
word_dict.append('animatronic')
word_dict.append('unevaluable')
word_dict.append('floccinaucinihilipilification')
word_dict.append('oreo')
word_dict.append('hypergraph')
word_dict.append('hypergraphs')
word_dict.append('hypergraphia')
word_dict.append('froyo')
word_dict.append('backstory')
word_dict.append('barista')
word_dict.append('biodiversity')
word_dict.append('blog')
word_dict.append('caffeinated')
word_dict.append('caregiver')
word_dict.append('chainsaw')
word_dict.append('conman')
word_dict.append('curated')
word_dict.append('curating')
word_dict.append('cyber')
word_dict.append('cyberspace')
word_dict.append('cytokines')
word_dict.append('daycare')
word_dict.append('deconstruct')
word_dict.append('deconstructing')
word_dict.append('deconstruction')
word_dict.append('disrespect')
word_dict.append('disrespected')
word_dict.append('dumpster')
word_dict.append('elven')
word_dict.append('emails')
word_dict.append('email')
word_dict.append('eukaryotic')
word_dict.append('hashtag')
word_dict.append('hijab')
word_dict.append('inbox')
word_dict.append('latte')
word_dict.append('macrophages')
word_dict.append('makeover')
word_dict.append('malware')
word_dict.append('megapixel')
word_dict.append('meme')
word_dict.append('metadata')
word_dict.append('naysayers')
word_dict.append('podcast')
word_dict.append('poo')
word_dict.append('proactively')
word_dict.append('ramen')
word_dict.append('remastered')
word_dict.append('screenshot')
word_dict.append('selfie')
word_dict.append('slideshow')
word_dict.append('smartphone')
word_dict.append('snowboard')
word_dict.append('soulmate')
word_dict.append('sourced')
word_dict.append('sourcing')
word_dict.append('standalone')
word_dict.append('sustainability')
word_dict.append('sweatpants')
word_dict.append('teabag')
word_dict.append('telecom')
word_dict.append('texting')
word_dict.append('timeline')
word_dict.append('twerk')
word_dict.append('username')
word_dict.append('webinar')
word_dict.append('covid')
word_dict.append('website')
word_dict.append('coronavirus')
word_dict.append('whiteboard')
word_dict.append('walkaround')
word_dict.append('sandcastle')
word_dict.append('comorbidity')
word_dict.append('uncopyrightable')
word_dict.append('blepharo')
word_dict.append('blepharon')
word_dict.append('abled')
word_dict.append('penne')
word_dict.append('affused')
word_dict.append('affusing')
word_dict.append('stenosis')
word_dict.append('stenotic')
word_dict.append('sturdier')
word_dict.append('sturdies')
word_dict.append('peroxiding')
word_dict.append('peroxidic')
word_dict.append('gynecic')
word_dict.append('gynecidal')
word_dict.append('coevolved')
word_dict.append('coevolves')
word_dict.append('preobtruding')
word_dict.append('preobtrusion')
word_dict.append('kestrel')
word_dict.append('kestrels')
word_dict.append('aliyah')
word_dict.append('aliyahs')
word_dict.append('preobtruding')
word_dict.append('preobtrusion')
word_dict.append('coraco')
word_dict.append('procoracoid')
word_dict.append('cylindro')
word_dict.append('cylindric')
word_dict.append('epigonous')
word_dict.append('epigons')
word_dict.append('snailfishes')
word_dict.append('snailflower')
word_dict.append('outwards')
word_dict.append('outwarred')
word_dict.append('regeneratory')
word_dict.append('regeneratress')
word_dict.append('quadri')
word_dict.append('quadric')
word_dict.append('subsultory')
word_dict.append('subsultus')
word_dict.append('brigantine')
word_dict.append('brigantines')
word_dict.append('caduce')
word_dict.append('caducean')
word_dict.append('negotiator')
word_dict.append('preinferred')
word_dict.append('preinferring')
word_dict.append('middleware')
word_dict.append('middlewares')
word_dict.append('placeholders')
word_dict.append('fearmonger')
word_dict.append('fearmongering')
word_dict.append('rizz')
word_dict.append('zhuzh')
word_dict.append('doggo')
word_dict.append('padawan')
word_dict.append('simp')
word_dict.append('bingo')
word_dict.append('goated')
word_dict.append('bussin')
word_dict.append('cromulent')
word_dict.append('ngl')
word_dict.append('tfw')
word_dict.append('ttyl')
word_dict.append('genai')
word_dict.append('rotoscope')
word_dict.append('smishing')
word_dict.append('passkey')
word_dict.append('kaggle')
word_dict.append('uap')
word_dict.append('nyctinasty')
word_dict.append('rewild')
word_dict.append('crate-dig')
word_dict.append('cratedig')
word_dict.append('tinyhouse')
word_dict.append('jorts')
word_dict.append('cutscene')
word_dict.append('nonplayer')
word_dict.append('nerf')
word_dict.append('speedrun')
word_dict.append('ragequit')
word_dict.append('ragequits')
word_dict.append('jumpscare')
word_dict.append('coldopen')
word_dict.append('vanitycard')
word_dict.append('grammable')
word_dict.append('instagrammable')
word_dict.append('instagram')
word_dict.append('facebook')
word_dict.append('tiktok')
word_dict.append('wechat')
word_dict.append('weixin')
word_dict.append('twitter')
word_dict.append('twit')
word_dict.append('doomscroll')
word_dict.append('edgelord')
word_dict.append('finsta')
word_dict.append('quietquit')
word_dict.append('qq')
word_dict.append('prosocial')
word_dict.append('cape')
word_dict.append('chefskiss')
word_dict.append('stagiare')
word_dict.append('stage')
word_dict.append('cheffy')
word_dict.append('emping')
word_dict.append('jollofrice')
word_dict.append('smashburget')
word_dict.append('carboncapture')
word_dict.append('nurdle')
word_dict.append('kayfabe')
word_dict.append('tabata')
word_dict.append('kissandcry')
word_dict.append('battlerope')
word_dict.append('bracketology')
word_dict.append('beastmode')
word_dict.append('girlboss')
word_dict.append('microtransaction')
word_dict.append('samsung')
word_dict.append('huawei')
word_dict.append('hyundai')
word_dict.append('kia')
word_dict.append('nissan')
word_dict.append('mitsubishi')
word_dict.append('suzuki')
word_dict.append('mazda')
word_dict.append('lamborghini')
word_dict.append('ferrari')
word_dict.append('klingkling')
word_dict.append('kling')
word_dict.append('vvs')
word_dict.append('alphago')
word_dict.append('gompyo')
word_dict.append('openai')
word_dict.append('microsoft')
word_dict.append('azure')
word_dict.append('worldcup')
word_dict.append('asiancup')
word_dict.append('lck')
word_dict.append('championship')
word_dict.append('leaugeoflegend')
word_dict.append('damwon')
word_dict.append('google')
word_dict.append('meta')
word_dict.append('tesla')
word_dict.append('boa')
word_dict.append('nasdaq')
word_dict.append('hsbc')
word_dict.append('hongkongshanghai')
word_dict.append('hongkong')
word_dict.append('hong kong')
word_dict.append('hong')
word_dict.append('kong')
word_dict.append('taiwan')
word_dict.append('filipines')
word_dict.append('philipines')
word_dict.append('thailand')
word_dict.append('indonesia')
word_dict.append('malaysia')
word_dict.append('singapore')
word_dict.append('korea')
word_dict.append('canada')
word_dict.append('france')
word_dict.append('mexico')
word_dict.append('biden')
word_dict.append('spain')
word_dict.append('norway')
word_dict.append('sweden')
word_dict.append('finland')
word_dict.append('russia')
word_dict.append('ukraine')
word_dict.append('kazakhstan')
word_dict.append('vietnam')
word_dict.append('viet')
word_dict.append('nam')
word_dict.append('microtransaction')
word_dict.append('japan')
word_dict.append('australia')
word_dict.append('zealand')
word_dict.append('newzealand')
word_dict.append('seoul')
word_dict.append('busan')
word_dict.append('seongnam')
word_dict.append('gangwon')
word_dict.append('chungcheong')
word_dict.append('jeolla')
word_dict.append('jeonla')
word_dict.append('gyeongsang')
word_dict.append('gyungsang')
word_dict.append('bangkok')
word_dict.append('jakarta')
word_dict.append('bali')
word_dict.append('kualalumpur')
word_dict.append('kathmandu')
word_dict.append('nepal')
word_dict.append('tahiti')
word_dict.append('switzerland')
word_dict.append('swiss')
word_dict.append('germany')
word_dict.append('deutschland')
word_dict.append('netherlands')
word_dict.append('holland')
word_dict.append('portugal')
word_dict.append('porto')
word_dict.append('momory')
word_dict.append('avocadoland')
word_dict.append('yeardream')
word_dict.append('macbook')
word_dict.append('macbooks')
word_dict.append('ipad')
word_dict.append('ipads')
word_dict.append('iphone')
word_dict.append('iphones')
word_dict.append('airpod')
word_dict.append('airpods')
word_dict.append('starbucks')
word_dict.append('hollys')
word_dict.append('twosomeplace')
word_dict.append('twosome')
word_dict.append('caffebene')
word_dict.append('theventi')
word_dict.append('ediya')
word_dict.append('mammothcoffee')
word_dict.append('fiesta')
word_dict.append('banapresso')
word_dict.append('paulbassett')
word_dict.append('paiksdabang')
word_dict.append('composecoffee')
word_dict.append('coffeebean')
word_dict.append('konabeans')
word_dict.append('boongeobbang')
word_dict.append('bungeobbang')
word_dict.append('karrot')
word_dict.append('notion')
word_dict.append('slack')
word_dict.append('youtube')
word_dict.append('colab')
word_dict.append('linkedin')
word_dict.append('chatgpt')
word_dict.append('bard')
word_dict.append('github')
word_dict.append('xgboost')
word_dict.append('lightgbm')
word_dict.append('aespa')
word_dict.append('newjeans')
word_dict.append('superjunior')
word_dict.append('bigbang')
word_dict.append('tvxq')
word_dict.append('twice')
word_dict.append('momoland')
word_dict.append('seventeen')
word_dict.append('bts')
word_dict.append('bangtan')
word_dict.append('jungkook')
word_dict.append('jimin')
word_dict.append('rapmonster')
word_dict.append('suga')
word_dict.append('jin')
word_dict.append('j-hope')
word_dict.append('jhope')
word_dict.append('bangtanboys')
word_dict.append('army')
word_dict.append('armi')
word_dict.append('sonyeondan')
word_dict.append('fiftyfifty')
word_dict.append('blackpink')
word_dict.append('snsd')
word_dict.append('girlsgeneration')
word_dict.append('wondergirls')
word_dict.append('izone')
word_dict.append('ive')
word_dict.append('lesserafim')
word_dict.append('samaltman')
word_dict.append('sundarpichai')
word_dict.append('sundar')
word_dict.append('pichai')
word_dict.append('zuckerberg')
word_dict.append('elonmusk')
word_dict.append('lesserafim')
word_dict.append('whiteman')
word_dict.append('blackberry')
word_dict.append('teamfighttactics')
word_dict.append('teamfight')
word_dict.append('tacktics')
word_dict.append('loltochess')
word_dict.append('jynx')
word_dict.append('vi')
word_dict.append('yasuo')
word_dict.append('udyr')
word_dict.append('ahri')
word_dict.append('aatrox')
word_dict.append('akali')
word_dict.append('akshan')
word_dict.append('alistar')
word_dict.append('amumu')
word_dict.append('anivia')
word_dict.append('annie')
word_dict.append('aphelios')
word_dict.append('ashe')
word_dict.append('aurelion')
word_dict.append('aurelionsol')
word_dict.append('sol')
word_dict.append('azir')
word_dict.append('bard')
word_dict.append('belveth')
word_dict.append('blitzcrank')
word_dict.append('blitz')
word_dict.append('brand')
word_dict.append('braum')
word_dict.append('briar')
word_dict.append('caitlyn')
word_dict.append('camille')
word_dict.append('cassiopeia')
word_dict.append('chogath')
word_dict.append('cho')
word_dict.append('corki')
word_dict.append('corgi')
word_dict.append('darius')
word_dict.append('diana')
word_dict.append('drmundo')
word_dict.append('mundo')
word_dict.append('dr')
word_dict.append('draven')
word_dict.append('ekko')
word_dict.append('elise')
word_dict.append('evelynn')
word_dict.append('evelyn')
word_dict.append('ezreal')
word_dict.append('fiddlesticks')
word_dict.append('fiddlestick')
word_dict.append('fiora')
word_dict.append('fizz')
word_dict.append('galio')
word_dict.append('gangplank')
word_dict.append('garen')
word_dict.append('gnar')
word_dict.append('gragas')
word_dict.append('graves')
word_dict.append('gwen')
word_dict.append('hecarim')
word_dict.append('heimerdinger')
word_dict.append('dinger')
word_dict.append('illaoi')
word_dict.append('irelia')
word_dict.append('ivern')
word_dict.append('janna')
word_dict.append('jarvan')
word_dict.append('jarvaniv')
word_dict.append('jax')
word_dict.append('jhin')
word_dict.append('jinx')
word_dict.append('ksante')
word_dict.append('kaisa')
word_dict.append('kai`sa')
word_dict.append("kai'sa")
word_dict.append('kalista')
word_dict.append('karma')
word_dict.append('karthus')
word_dict.append('kassadin')
word_dict.append('katarina')
word_dict.append('kayle')
word_dict.append('kayn')
word_dict.append('kennen')
word_dict.append('khazix')
word_dict.append('kha')
word_dict.append('kindred')
word_dict.append('kled')
word_dict.append('kogmaw')
word_dict.append('leblanc')
word_dict.append('leesin')
word_dict.append('lee')
word_dict.append('leona')
word_dict.append('lillia')
word_dict.append('lissandra')
word_dict.append('lucian')
word_dict.append('lulu')
word_dict.append('lux')
word_dict.append('luxo')
word_dict.append('lexus')
word_dict.append('malphite')
word_dict.append('mazahar')
word_dict.append('maokai')
word_dict.append('masteryi')
word_dict.append('yi')
word_dict.append('milio')
word_dict.append('missfortune')
word_dict.append('mf')
word_dict.append('mordekaiser')
word_dict.append('morgana')
word_dict.append('naafiri')
word_dict.append('nami')
word_dict.append('nasus')
word_dict.append('nautilus')
word_dict.append('neeko')
word_dict.append('nidali')
word_dict.append('nidalee')
word_dict.append('nilah')
word_dict.append('nocturn')
word_dict.append('nunu')
word_dict.append('willump')
word_dict.append('olaf')
word_dict.append('orianna')
word_dict.append('ornn')
word_dict.append('pantheon')
word_dict.append('poppy')
word_dict.append('pyke')
word_dict.append('qiyana')
word_dict.append('quinn')
word_dict.append('rakan')
word_dict.append('rammus')
word_dict.append('reksai')
word_dict.append('rell')
word_dict.append('renataglasc')
word_dict.append('glasc')
word_dict.append('renata')
word_dict.append('renekton')
word_dict.append('rengar')
word_dict.append('riven')
word_dict.append('rumble')
word_dict.append('ryze')
word_dict.append('samira')
word_dict.append('sejuani')
word_dict.append('senna')
word_dict.append('seraphine')
word_dict.append('sett')
word_dict.append('shaco')
word_dict.append('shen')
word_dict.append('shyvana')
word_dict.append('singed')
word_dict.append('sion')
word_dict.append('sivir')
word_dict.append('skarner')
word_dict.append('sona')
word_dict.append('soraka')
word_dict.append('swain')
word_dict.append('skarner')
word_dict.append('sylas')
word_dict.append('teemo')
word_dict.append('thresh')
word_dict.append('tristana')
word_dict.append('trundle')
word_dict.append('tryndamere')
word_dict.append('twistedfate')
word_dict.append('twitch')
word_dict.append('udyr')
word_dict.append('urgot')
word_dict.append('varus')
word_dict.append('vayne')
word_dict.append('veigar')
word_dict.append('velkoz')
word_dict.append('vex')
word_dict.append('vi')
word_dict.append('viego')
word_dict.append('viktor')
word_dict.append('vladimir')
word_dict.append('volibear')
word_dict.append('warwick')
word_dict.append('wukong')
word_dict.append('xayah')
word_dict.append('xerath')
word_dict.append('xinzhao')
word_dict.append('zhao')
word_dict.append('yasuo')
word_dict.append('yone')
word_dict.append('yorick')
word_dict.append('yuumi')
word_dict.append('zac')
word_dict.append('zed')
word_dict.append('zeri')
word_dict.append('ziggs')
word_dict.append('zilean')
word_dict.append('zoe')
word_dict.append('zyra')
word_dict.append('faker')
word_dict.append('zeus')
word_dict.append('gumayusi')
word_dict.append('gumayushi')
word_dict.append('keria')
word_dict.append('oner')
word_dict.append('coevolved')
word_dict.append('coevolves')
word_dict.append('supercut')
word_dict.append('indianews')
word_dict.append('punchline')
word_dict.append('carpooling')
word_dict.append('ridesharing')
word_dict.append('homecooking')
word_dict.append('carpooling')
word_dict.append('skylovers')
word_dict.append('matlab')
word_dict.append('chappals')
word_dict.append('extinguished')
word_dict.append('probook')
word_dict.append('rulebook')
word_dict.append('safeplace')
word_dict.append('technews')
word_dict.append('sandiego')
word_dict.append('sunsails')
word_dict.append('roadsigns')
word_dict.append('roadsign')
word_dict.append('tasmania')
word_dict.append('chyron')
word_dict.append('izzie')
word_dict.append('bhopal')
word_dict.append('buyblack')
word_dict.append('ganapathi')
word_dict.append('ganapati')
word_dict.append('sunsail')
word_dict.append('bhabhi')
word_dict.append('unprecede')
word_dict.append('qualitytime')
word_dict.append('nospills')
word_dict.append('freetesting')

# %%
list_of_countries = ["Afghanistan", "Albania", "Algeria", "Andorra", "Angola", "Antigua", "Argentina", "Armenia", "Australia", "Austria", "Azerbaijan",
                    "Bahamas", "Bahrain", "Bangladesh", "Barbados", "Belarus", "Belgium", "Belize", "Benin", "Bhutan", "Bolivia", "Bosnia", "Herzegovina", "Botswana", "Brazil", "Brunei", "Bulgaria", "Burkina", "Burundi",
                    "Cambodia", "Cameroon", "Canada", "Cape", "Verde", "Central", "African", "Chad", "Chile", "China", "Colombia", "Comoros", "Congo", "Costa", "Rica", "Croatia", "Cuba", "Cyprus", "Czech Republic", "Curaçao",
                    "Denmark", "Djibouti", "Dominica", "Dominican Republic",
                    "Timor", "Ecuador", "Egypt", 'El', "Salvador", "Equatorial", "Guinea", "Eritrea", "Estonia", "Ethiopia",
                    "Fiji", "Finland", "France",
                    "Gabon", "Gambia", "Georgia", "Germany", "Ghana", "Greece", "Grenada", "Guatemala", "Guinea", "Guinea", "Bissau", "Guinea-Bissau", "Guyana",
                    "Haiti", "Honduras", "Hungary",
                    "Iceland", "India", "Indonesia", "Iran", "Iraq", "Ireland", "Israel", "Italy", "Ivory", "Coast","Ivory Coast", 
                    "Jamaica", "Japan", "Jordan",
                    "Kazakhstan", "Kenya", "Kiribati", "Korea", "Kosovo", "Kuwait", "Kyrgyzstan",
                    "Laos", "Latvia", "Lebanon", "Lesotho", "Liberia", "Libya", "Liechtenstein", "Lithuania", "Luxembourg",
                    "Macedonia", "Madagascar", "Malawi", "Malaysia", "Maldives", "Mali", "Malta", "Marshall", "Mauritania", "Mauritius", "Mexico", "Micronesia", "Moldova", "Monaco", "Mongolia", "Montenegro", "Morocco", "Mozambique", "Myanmar", "Burma",
                    "Namibia", "Nauru", "Nepal", "Netherlands", "New Zealand", "Zealand", "Nicaragua", "Niger", "Nigeria", "Norway",
                    "Oman",
                    "Pakistan", "Palau", "Panama", "PapuaNewGuinea", "Papua", "Guinea", "Paraguay", "Peru", "Philippines", "Poland", "Portugal",
                    "Qatar",
                    "Romania", "Russian", "Rwanda",
                    "St", "St Kitts & Nevis","Kitts", "Nevis", "St Lucia", "Lucia", "Saint", "Vincent", "Grenadines", "Saint Vincent & the Grenadines", "Samoa", "San", "San Marino", "Marino", "Sao", "Tome", "Principe", "Sao Tome & Principe", "Saudi", "Arabia", "Saudi Arabia", "Senegal", "Serbia", "Seychelles", "Sierra", "Leone", "Sierra Leone", "Singapore", "Singapura", "Slovakia", "Slovenia", "Solomon", "Islands", "Solomon Islands", "Somalia", "Africa", "Sudan", "South Africa", "South Sudan", "Spain", "Sri", "Lanka", "Sri Lanka", "SriLanka", "Sudan", "Suriname", "Swaziland", "Sweden", "Switzerland", "Syria",
                    "Taiwan", "Tajikistan", "Tanzania", "Thailand", "Togo", "Tonga", "Trinidad", "Tobago", "TrinidadTobago", "Tunisia", "Turkey", "Turkmenistan", "Tuvalu",
                    "Uganda", "Ukraine", "UAE", "Arab", "Emirates", "United Arab Emirates", "UK", "United Kingdom", "USA", "US", "UnitedStates", "Uruguay", "Uzbekistan",
                    "Vanuatu", "Vatican", "Vatican City", "Venezuela", "Vietnam",
                    "Yemen",
                    "Zambia", "Zimbabwe"]
for country in list_of_countries:
    word_dict.append(country.lower().replace(' ', ''))

# %%
word_dict.remove('ocurred')
word_dict.remove('greing')
word_dict.remove('overlubricatio')
word_dict.remove('etwite')
word_dict.remove('coloslossuses')
word_dict.remove('preinferredpreinferring')
word_dict.remove('affusedaffusing')
word_dict.remove('stegnosisstegnotic')
word_dict.remove('sturdiersturdies')
word_dict.remove('peroxidicperoxiding')
word_dict.remove('gynecicgynecidal')
word_dict.remove('preobtrudingpreobtrusion')
word_dict.remove('kestrelkestrels')
word_dict.remove('aliyahaliyahs')
word_dict.remove('coracoprocoracoid')
word_dict.remove('cylindrocylindric')
word_dict.remove('epigonousepigons')
word_dict.remove('snailfishessnailflower')
word_dict.remove('outwardsoutwarred')
word_dict.remove('regeneratoryregeneratress')
word_dict.remove('quadriquadric')
word_dict.remove('subsultorysubsultus')
word_dict.remove('brigantinebrigantines')
word_dict.remove('caducecaducean')
word_dict.remove('negqtiator')
word_dict.remove('penetrolqgy')

# %%
missing_words_list = open('./missing_words_from_dwyl.txt', 'r', encoding='utf-8')
mw_list = missing_words_list.read()
mw_list.split('\n')
for word in mw_list:
    word_dict.append(word)

# %%
word_dict=list(set(word_dict))

# %%
co = 0
for word in word_dict:
    if co == 5:
        break
    if word.startswith('y'):
        print(word)
        co += 1
# Out:
# yoghourt
# yuch
# yurt
# yore
# yawler

# %%
import json
word_dict_fixed = {}
for word in word_dict:
    word_dict_fixed[word] = 1
with open('word_dict.json', 'w') as file:
    # Dump the existing_data dictionary which now contains the updated data
    json.dump(word_dict_fixed, file, indent=4)
